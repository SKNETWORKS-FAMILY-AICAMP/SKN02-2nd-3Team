# %%
import pandas as pd

# %%
# 데이터 불러오기
df = pd.read_csv('./E Commerce Dataset.csv')

# %%
# 데이터 확인
df.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
# ...

# %%
# 데이터프레임 정보 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5630 entries, 0 to 5629
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CustomerID                   5630 non-null   int64
#  1   Churn                        5630 non-null   int64
#  2   Tenure                       5366 non-null   float64
#  3   PreferredLoginDevice         5630 non-null   object
#  4   CityTier                     5630 non-null   int64
#  5   WarehouseToHome              5379 non-null   float64
#  6   PreferredPaymentMode         5630 non-null   object
#  7   Gender                       5630 non-null   object
#  8   HourSpendOnApp               5375 non-null   float64
#  9   NumberOfDeviceRegistered     5630 non-null   int64
#  10  PreferedOrderCat             5630 non-null   object
#  11  SatisfactionScore            5630 non-null   int64
#  12  MaritalStatus                5630 non-null   object
# ...

# %%
# 결측치 확인
df.isna().sum()
# Out:
# CustomerID                       0
# Churn                            0
# Tenure                         264
# PreferredLoginDevice             0
# CityTier                         0
# WarehouseToHome                251
# PreferredPaymentMode             0
# Gender                           0
# HourSpendOnApp                 255
# NumberOfDeviceRegistered         0
# PreferedOrderCat                 0
# SatisfactionScore                0
# MaritalStatus                    0
# NumberOfAddress                  0
# Complain                         0
# OrderAmountHikeFromlastYear    265
# CouponUsed                     256
# OrderCount                     258
# DaySinceLastOrder              307
# CashbackAmount                   0
# dtype: int64

# %%
# 데이터 범주 일치화
df.replace(['Mobile Phone', 'Credit Card', 'Mobile Phone'], ['Phone', 'CC', 'Mobile'], inplace=True)

# %%
df.describe()
# Out:
#          CustomerID        Churn       Tenure     CityTier  WarehouseToHome  \
# count   5630.000000  5630.000000  5366.000000  5630.000000      5379.000000
# mean   52815.500000     0.168384    10.189899     1.654707        15.639896
# std     1625.385339     0.374240     8.557241     0.915389         8.531475
# min    50001.000000     0.000000     0.000000     1.000000         5.000000
# 25%    51408.250000     0.000000     2.000000     1.000000         9.000000
# 50%    52815.500000     0.000000     9.000000     1.000000        14.000000
# 75%    54222.750000     0.000000    16.000000     3.000000        20.000000
# max    55630.000000     1.000000    61.000000     3.000000       127.000000
#
#        HourSpendOnApp  NumberOfDeviceRegistered  SatisfactionScore  \
# count     5375.000000               5630.000000        5630.000000
# mean         2.931535                  3.688988           3.066785
# std          0.721926                  1.023999           1.380194
# ...

# %%
# 범주 데이터 원 핫 인코딩

dummies = pd.get_dummies(df)

# %%
corr_matrix = dummies.corrwith(df["Churn"])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 상관 관계 시리즈를 DataFrame으로 변환
corr_df = corr_matrix.to_frame(name='Correlation')

# 히트맵 그리기
plt.figure(figsize=(8, 12))  # 히트맵의 크기 설정
sns.heatmap(corr_df.sort_values(by='Correlation', ascending=False), 
            annot=True, cmap='coolwarm', cbar=True, vmin=-1, vmax=1)
plt.title('Correlation with Churn')
plt.show()

# %%
corr = dummies['Churn'].corr(dummies["OrderCount"])

# %%
order = dummies[["OrderCount", "Churn"]]

# %%
order
# Out:
#       OrderCount  Churn
# 0            1.0      1
# 1            1.0      1
# 2            1.0      1
# 3            1.0      1
# 4            1.0      1
# ...          ...    ...
# 5625         2.0      0
# 5626         2.0      0
# 5627         2.0      0
# 5628         2.0      0
# 5629         2.0      0
#
# [5630 rows x 2 columns]

# %%
order = order.dropna()
orderMoreThanTwo= order >2

# %%
df.dropna()
# Out:
#       CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  \
# 0          50001      1     4.0               Mobile         3
# 3          50004      1     0.0                Phone         3
# 5          50006      1     0.0             Computer         1
# 11         50012      1    11.0               Mobile         1
# 12         50013      1     0.0                Phone         1
# ...          ...    ...     ...                  ...       ...
# 5624       55625      0     1.0               Mobile         3
# 5625       55626      0    10.0             Computer         1
# 5627       55628      0     1.0               Mobile         1
# 5628       55629      0    23.0             Computer         3
# 5629       55630      0     8.0               Mobile         1
#
#       WarehouseToHome PreferredPaymentMode  Gender  HourSpendOnApp  \
# 0                 6.0           Debit Card  Female             3.0
# 3                15.0           Debit Card    Male             2.0
# ...

# %%
left_col = pd.Series([False,False,False, True, True, True])
right_col = pd.Series([1,2,3,4,5,6])

left_col.corr(right_col)
# Out:
# 0.8783100656536799

# %%
order = dummies[["NumberOfDeviceRegistered", "Churn"]]
order = order.dropna()
orderMoreThanTwo= dummies['NumberOfDeviceRegistered'] >5
order['Churn'].corr(orderMoreThanTwo)
# Out:
# 0.08155096968834573

# %%
df["MaritalStatus"].value_counts()
# Out:
# MaritalStatus
# Married     2986
# Single      1796
# Divorced     848
# Name: count, dtype: int64

# %%
import pandas as pd

# df["Gender"]와 df["MaritalStatus"] 열을 병합하여 교차 테이블 생성
cross_tab = pd.crosstab(df["Gender"], df["MaritalStatus"])

# 교차 테이블 출력
print(cross_tab)
# Out:
# MaritalStatus  Divorced  Married  Single
# Gender
# Female              348     1140     758
# Male                500     1846    1038

# %%
df['Combined'] = df['Gender'] + ' - ' + df['MaritalStatus']
gender_marital = df[['Combined', 'Churn']]

# %%
gender_marital_dummies = pd.get_dummies(gender_marital)

# %%
gender_marital_dummies.corr()
# Out:
#                                Churn  Combined_Female - Divorced  \
# Churn                       1.000000                   -0.020888
# Combined_Female - Divorced -0.020888                    1.000000
# Combined_Female - Married  -0.094443                   -0.129336
# Combined_Female - Single    0.083943                   -0.101244
# Combined_Male - Divorced   -0.013669                   -0.080134
# Combined_Male - Married    -0.079712                   -0.179280
# Combined_Male - Single      0.143477                   -0.122036
#
#                             Combined_Female - Married  \
# Churn                                       -0.094443
# Combined_Female - Divorced                  -0.129336
# Combined_Female - Married                    1.000000
# Combined_Female - Single                    -0.198751
# Combined_Male - Divorced                    -0.157310
# Combined_Male - Married                     -0.351941
# Combined_Male - Single                      -0.239567
#
# ...

# %%
coupon_counts = df["CouponUsed"].value_counts()

# %%
import matplotlib.pyplot as plt

coupon_counts = df["CouponUsed"].value_counts()
# 분포 그래프 그리기
plt.figure(figsize=(10, 6))
coupon_counts.sort_index().plot(kind='bar')
plt.title('Coupon Used Distribution')
plt.xlabel('Number of Coupons Used')
plt.ylabel('Count(Users)')
plt.xticks(rotation=45)
plt.show()

# %%
df["PreferredPaymentMode"].value_counts()
# Out:
# PreferredPaymentMode
# Debit Card          2314
# CC                  1774
# E wallet             614
# UPI                  414
# COD                  365
# Cash on Delivery     149
# Name: count, dtype: int64

# %%
gender_marital.value_counts()
# Out:
# Combined           Churn
# Male - Married     0        1614
# Female - Married   0        1028
# Male - Single      0         746
# Female - Single    0         570
# Male - Divorced    0         424
# Female - Divorced  0         300
# Male - Single      1         292
# Male - Married     1         232
# Female - Single    1         188
# Female - Married   1         112
# Male - Divorced    1          76
# Female - Divorced  1          48
# Name: count, dtype: int64

# %%
cashback_ordercount= df[['HourSpendOnApp', 'NumberOfDeviceRegistered',"Churn"]]

# %%
cashback_ordercount
# Out:
#       HourSpendOnApp  NumberOfDeviceRegistered  Churn
# 0                3.0                         3      1
# 1                3.0                         4      1
# 2                2.0                         4      1
# 3                2.0                         4      1
# 4                NaN                         3      1
# ...              ...                       ...    ...
# 5625             3.0                         2      0
# 5626             3.0                         5      0
# 5627             3.0                         2      0
# 5628             4.0                         5      0
# 5629             3.0                         2      0
#
# [5630 rows x 3 columns]

# %% [markdown]
# # 파생변수 생성

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

left_col,right_col=("CityTier","WarehouseToHome")

cashback_ordercount= df[[left_col,right_col,"Churn"]]
cashback_ordercount[left_col] = scaler.fit_transform(cashback_ordercount[left_col].values.reshape(-1, 1))
cashback_ordercount[right_col] = scaler.fit_transform(cashback_ordercount[right_col].values.reshape(-1, 1))

cashback_ordercount['Churn'].corr(cashback_ordercount[left_col]+cashback_ordercount[right_col])
# Out:
# /tmp/ipykernel_25442/1153376189.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cashback_ordercount[left_col] = scaler.fit_transform(cashback_ordercount[left_col].values.reshape(-1, 1))
# /tmp/ipykernel_25442/1153376189.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cashback_ordercount[right_col] = scaler.fit_transform(cashback_ordercount[right_col].values.reshape(-1, 1))
# 0.12400302430290078

# %%
dummies
# Out:
#       CustomerID  Churn  Tenure  CityTier  WarehouseToHome  HourSpendOnApp  \
# 0          50001      1     4.0         3              6.0             3.0
# 1          50002      1     NaN         1              8.0             3.0
# 2          50003      1     NaN         1             30.0             2.0
# 3          50004      1     0.0         3             15.0             2.0
# 4          50005      1     0.0         1             12.0             NaN
# ...          ...    ...     ...       ...              ...             ...
# 5625       55626      0    10.0         1             30.0             3.0
# 5626       55627      0    13.0         1             13.0             3.0
# 5627       55628      0     1.0         1             11.0             3.0
# 5628       55629      0    23.0         3              9.0             4.0
# 5629       55630      0     8.0         1             15.0             3.0
#
# ...

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler


# 데이터 표준화
scaler = StandardScaler()
dummies.dropna(inplace=True)
y= dummies["Churn"]
X = dummies.drop(columns=['Churn'])

X_scaled = scaler.fit_transform(dummies)

# Perform PCA
pca = PCA(n_components=4)
pca_features = pca.fit_transform(X_scaled)

# Perform clustering using K-means
kmeans = KMeans(n_clusters=8)
kmeans.fit(pca_features)

# Get cluster labels
cluster_labels = kmeans.labels_

# %%
# Plot the clusters
plt.scatter(pca_features[:, 3], pca_features[:, 2], c=cluster_labels, cmap='viridis')
plt.xlabel('PCA Feature 1')
plt.ylabel('PCA Feature 2')
plt.title('Clustering Results')
plt.show()
